# %% [markdown]
# # Regressão Linear

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Parte 1

# %% [markdown]
# 1. Implemente a regressão linear simples (uma variável)
# $$ y = \beta_0 + \beta_1 x $$
#
# Cálculo dos coeficientes
# $$ \beta_1 = \frac{\sum_{i=0}^{n-1}{ (x_i - mean(x)) \times (y_i - mean(y)) }}{\sum_{i=0}^{n-1}{(x_i - mean(x))^2}} $$
#
# $$ \beta_0 = mean(y) - \beta_1 \times mean(x) $$

# %%
class RegressaoSimples():
    def __init__(self):
        pass
    
    def fit(self, x, y):
        sum1 = 0
        sum2 = 0
        mean_x = np.mean(x)
        mean_y = np.mean(y)
        
        for i in range(len(x)):
            sum1 += (x[i] - mean_x) * (y[i] - mean_y)
            sum2 += (x[i] - mean_x) ** 2
        
        #Calculando os coeficientes
        self.b1 = sum1 / sum2
        self.b0 = mean_y - self.b1 * mean_x
        
    def predict(self, x):
        y_predict = []
        for i in range(len(x)):
            y_predict.append(self.b0 + self.b1 * x[i])
        return y_predict
    
    def coef(self):
        return self.b0, self.b1

# %% [markdown]
# 2. Implemente a regressão linear múltipla. No treinamento, adicione o termo de bias incluindo uma coluna de 1’s na matriz de amostras
# $$ y = \beta_1 x_1 + \beta_2 x_2 + \cdots + \beta_n x_n + \beta_0$$
# Cálculo dos coeficientes
# $$ \beta = (x^{T} x)^{-1} x^{T} y $$

# %%
class RegressaoMultipla():
    def __init__(self):
        pass
    
    def fit(self, x, y):
        
        #Adicionando o termo de bias (incluindo uma coluna de 1's na matriz de amostras)
        x = np.c_[x, np.ones(x.shape[0])]
        
        #Calculando os coeficientes
        self.b = np.matmul(np.matmul(np.linalg.inv(np.matmul(np.transpose(x), x)), np.transpose(x)), y)
        
    def predict(self, x):
        self.y = self.b[0]
        for i in range(1, self.b.shape[0]):
            self.y += self.b[i] * x[:, i-1]
            
        return self.y
    
    def coef(self):
        return self.b

# %% [markdown]
# 3. Implemente as funções

# %% [markdown]
#     a. RSS(y_true, y_predict)
# $$ RSS = \sum_{i=0}^{n-1}{ (y_i - \hat{y_i})^2 } $$

# %%
def RSS(y_true, y_predict):
    soma = 0
    for i,j in enumerate(y_true):
        soma += (j - y_predict[i])**2
    
    return soma

# %% [markdown]
#     b. RSE(y_true, y_predict)
# $$ RSE = \sqrt{ \frac {1} {n-2}\sum_{i=0}^{n-1}{ (y_i - \hat{y_i})^2 }} $$

# %%
def RSE(y_true, y_predict):
    sum_y = 0
    for i,j in enumerate(y_true):
        sum_y += (j - y_predict[i])**2
        
    rse = np.sqrt(sum_y / ((i+1) - 2))
    
    return rse

# %% [markdown]
#     c. R2(y_true, y_predict)
# $$ R^2 = 1 - \frac{RSS}{TSS} $$
#
#
# $$ TSS = \sum_{i=0}^{n-1}{ (y_i - \bar{y})^2 } $$

# %%
def TSS(y_true, y_mean):
    soma = 0
    for i in y_true:
        soma += (i - y_mean)**2
    
    return soma

# %%
def R2(y_true, y_predict):
    y_mean = np.mean(y_true)
    
    var_sum_rss = RSS(y_true, y_predict)
    var_sum_tss = TSS(y_true, y_mean)
    
    r2 = 1 - (var_sum_rss/var_sum_tss)
    return r2

# %% [markdown]
#     d. MAE(y_true, y_predict)
# $$ MAE = \frac{1}{n} \sum_{i=0}^{n-1}{ \vert y_i - \hat{y}_i \vert } $$

# %%
def MAE(y_true, y_predict):
    sum_y = 0
    for i,j in enumerate(y_true):
        sum_y += abs(j - y_predict[i])
        
    mae = sum_y / (i+1)
    
    return mae

# %% [markdown]
# #### Parte 2

# %% [markdown]
# 1. Carregue o conjunto de dados Advertising.csv

# %%
#Carregando o conjunto de dados
dataset = "Advertising.csv"
dados = np.loadtxt(dataset, skiprows=1, delimiter=",")

# %%
#Mostrando alguns dados
dados[:6]
# Out:
# array([[  1. , 230.1,  37.8,  69.2,  22.1],
#        [  2. ,  44.5,  39.3,  45.1,  10.4],
#        [  3. ,  17.2,  45.9,  69.3,   9.3],
#        [  4. , 151.5,  41.3,  58.5,  18.5],
#        [  5. , 180.8,  10.8,  58.4,  12.9],
#        [  6. ,   8.7,  48.9,  75. ,   7.2]])

# %%
TV = dados[:,1]
radio = dados[:,2]
newspaper = dados[:,3]
sales = dados[:,4]

# %%
#Para regressão múltipla
x = dados[:, 1:4]

# %% [markdown]
# 2. Aplique a regressão linear simples para
#
#     i) variável TV contra Sales,
#
#     ii) variável Radio contra Sales
#
#     iii) variável Newspaper contra Sales

# %%
#i) variável TV contra Sales
model1 = RegressaoSimples()
model1.fit(TV, sales)
sales_predict = model1.predict(TV)
sales_predict
# Out:
# [17.970774512765534,
#  9.14797404839708,
#  7.8502237645756425,
#  14.234394574730185,
#  15.627218139417664,
#  7.446162320894975,
#  9.765950374026335,
#  12.74649772917667,
#  7.441408656851673,
#  16.53041430764504,
#  10.174765481750304,
#  17.23871025009703,
#  8.163965591433572,
#  11.667415991347124,
#  16.734821861507022,
#  16.32125308973975,
#  10.255577770486438,
#  20.409404166979442,
#  10.322129067092666,
#  14.034740684911505,
#  17.4145958196992,
#  18.317791987926576,
#  7.6600772028435635,
#  17.885208559986097,
#  9.99412624810483,
#  19.52997631896858,
#  13.825579467006218,
#  18.446140917095732,
#  18.859709688863003,
#  10.388680363698892,
#  20.95607553195917,
#  12.399480254015627,
#  11.653154999217218,
#  19.658325248137736,
#  11.581850038567687,
#  20.851494923006527,
#  19.720122880700657,
#  10.583580589474273,
#  9.081422751790852,
#  17.87094756785619,
#  16.65876323681419,
#  15.446578905772189,
#  20.989351180262283,
#  16.86792445471948,
#  8.225763223996498,
#  15.35625928894945,
#  11.29663019596957,
#  18.436633589009126,
#  17.832918255509774,
#  10.212794794096721,
#  16.53041430764504,
#  11.805272248602881,
#  17.319522538833162,
#  15.712784092197099,
#  19.520468990881973,
#  16.487631331255322,
#  7.379611024288748,
#  13.507083976104983,
#  17.053317352408254,
#  17.04856368836495,
#  9.575803812294257,
#  19.45391769427575,
#  18.408111604749315,
#  11.914606521598825,
#  13.264647109896584,
#  10.312621739006062,
#  8.529997722767824,
#  13.654447561447347,
#  18.317791987926576,
#  17.338537195006374,
#  16.49713865934192,
#  12.252116668673265,
#  8.306575512732632,
#  13.183834821160453,
#  17.176912617534107,
#  7.835962772445736,
#  8.339851161035746,
#  12.760758721306576,
#  15.578299879142287,
#  16.30571808882352,
#  12.947561842625941,
#  15.24467197846142,
#  12.674096350264575,
#  13.554655235668175,
#  15.151693711058556,
#  14.861820289155506,
#  15.075123373197373,
#  17.86994070513054,
#  13.521839376584811,
#  13.330413531931855,
#  12.641280491181211,
#  15.578299879142287,
#  13.97579209390468,
#  13.620286953834903,
#  13.751550390168358,
#  12.652219110875665,
#  15.441567132961605,
#  13.620286953834903,
#  12.482670505611617,
#  12.936623222931486,
#  14.238318966571592,
#  15.233733358766965,
#  13.751550390168358,
#  13.160864926667807,
#  16.68310046828221,
#  13.571063165209857,
#  14.878228218697188,
#  15.107939232280737,
#  13.204619405445627,
#  13.02960149033435,
#  16.40963497592084,
#  13.76795831971004,
#  15.118877851975192,
#  12.854583575223076,
#  12.526424984389436,
#  14.708679613433143,
#  12.827237025986939,
#  14.703210303585914,
#  12.466262576069935,
#  14.81806581037769,
#  15.939274329059291,
#  12.816298406292486,
#  12.860052885070305,
#  15.61658504807288,
#  13.472615587959766,
#  12.444385336681027,
#  13.056948039570488,
#  16.486205313782023,
#  14.42427550137732,
#  14.232849656724364,
#  14.478968599849594,
#  12.843644955528621,
#  12.827237025986939,
#  14.77431133159987,
#  13.002254941098215,
#  13.478084897806992,
#  14.375051712752274,
#  15.014960964877872,
#  13.128049067584444,
#  14.413336881682866,
#  12.870991504764758,
#  12.66315773057012,
#  15.113408542127964,
#  13.680449362154404,
#  14.823535120224916,
#  14.243788276418819,
#  14.030485192376952,
#  15.047776823961236,
#  13.751550390168358,
#  12.756135997972985,
#  12.646749801028438,
#  16.98938181972694,
#  13.532777996279265,
#  13.412453179640265,
#  15.501729541281104,
#  12.70144289950071,
#  13.35776008116799,
#  14.943859936863918,
#  13.281189743306808,
#  13.05147872972326,
#  13.067886659264943,
#  14.637578585419186,
#  13.46167696826531,
#  14.276604135502183,
#  13.64763350307104,
#  13.314005602390173,
#  12.80535978659803,
#  13.849997967418451,
#  13.97579209390468,
#  16.278371539587386,
#  13.992200023446362,
#  13.42339179933472,
#  13.806243488640632,
#  13.346821461473537,
#  12.553771533625573,
#  13.631225573529358,
#  12.668627040417347,
#  12.679565660111802,
#  14.079708981002,
#  12.548302223778347,
#  12.679565660111802,
#  13.106171828195533,
#  12.794421166903575,
#  12.70144289950071,
#  15.972090188142655,
#  12.827237025986939]

# %% [markdown]
#     a. Reporte o RSS, RSE, R2 e o MAE para cada um

# %%
#i) variável TV contra Sales
print("RSS: ", RSS(sales, sales_predict))
print("RSE: ", RSE(sales, sales_predict))
print("R2: ", R2(sales, sales_predict))
print("MAE: ", MAE(sales, sales_predict))
# Out:
# RSS:  2102.5305831313517
# RSE:  3.258656368650463
# R2:  0.6118750508500708
# MAE:  2.5498060389274864

# %%
#ii) variável Radio contra Sales
print("RSS: ", RSS(sales, sales_predict2))
print("RSE: ", RSE(sales, sales_predict2))
print("R2: ", R2(sales, sales_predict2))
print("MAE: ", MAE(sales, sales_predict2))
# Out:
# RSS:  3618.4795490250863
# RSE:  4.274944354901059
# R2:  0.33203245544529514
# MAE:  3.320218797642066

# %%
#iii) variável Newspaper contra Sales
print("RSS: ", RSS(sales, sales_predict3))
print("RSE: ", RSE(sales, sales_predict3))
print("R2: ", R2(sales, sales_predict3))
print("MAE: ", MAE(sales, sales_predict3))
# Out:
# RSS:  5134.804544111939
# RSE:  5.092480366520192
# R2:  0.0521204454443045
# MAE:  4.146559743838488

# %% [markdown]
#     b. Reporte os coeficientes para cada um

# %%
#i) variável TV contra Sales
print("Coeficiente B0: ", model1.coef()[0])
print("Coeficiente B1: ", model1.coef()[1])
# Out:
# Coeficiente B0:  7.032593549127704
# Coeficiente B1:  0.04753664043301969

# %%
#ii) variável Radio contra Sales
print("Coeficiente B0: ", model2.coef()[0])
print("Coeficiente B1: ", model2.coef()[1])
# Out:
# Coeficiente B0:  9.311638095158287
# Coeficiente B1:  0.20249578339243954

# %%
#iii) variável Newspaper contra Sales
print("Coeficiente B0: ", model3.coef()[0])
print("Coeficiente B1: ", model3.coef()[1])
# Out:
# Coeficiente B0:  12.351407069278162
# Coeficiente B1:  0.05469309847227332

# %% [markdown]
#     c. Que conclusão podemos tirar ao analisar as medidas de erro e os parâmetros sobre a relação das variáveis TV, Radio e Newspaper com a variável alvo Sales? Todas variáveis tem relação com Sales?

# %% [markdown]
# Com os erros calculados acima, é perceptível que a correlação entre TV e sales é maior que as outras variáveis e sales. Todas as variáveis possuem relação com sales, porém newspaper obteve um resultado mais alto nas métricas calculadas, ou seja, newspaper tem uma correlação menor com sales. As correlações estão mostradas em seguida.

# %%
print("Correlação entre as variáveis TV e sales: ", np.corrcoef(TV, sales)[0][1])
print("Correlação entre as variáveis radio e sales: ", np.corrcoef(radio, sales)[0][1])
print("Correlação entre as variáveis newspaper e sales: ", np.corrcoef(newspaper, sales)[0][1])
# Out:
# Correlação entre as variáveis TV e sales:  0.7822244248616061
# Correlação entre as variáveis radio e sales:  0.5762225745710551
# Correlação entre as variáveis newspaper e sales:  0.22829902637616528

# %% [markdown]
# 3. Aplique a regressão linear múltipla na matriz de observações completa contra Sales

# %%
modelo = RegressaoMultipla()
modelo.fit(x, sales)
sales_p = modelo.predict(x)
sales_p
# Out:
# array([246.75844867, 140.93848748, 206.90589331, 200.49024186,
#        205.75192596, 222.05194509,  79.91611103,  56.7778545 ,
#          4.60383343, 100.01581918,  83.62270405,  52.25381692,
#        198.16917249,  39.57955981, 173.67951857, 192.30228918,
#        347.82351567, 217.0470535 ,  66.85244867,  83.92422701,
#        198.12867411, 113.86139963, 148.28677745, 120.06853536,
#         65.55978775, 106.91501757,  63.98631157, 112.59506213,
#        114.22448335, 133.24607023, 182.19686631, 134.75388084,
#        106.53600713,  50.98025409,  39.83441611,  79.82774648,
#         65.01343081, 148.38494894, 111.29872418, 137.03595484,
#        131.06886105, 147.11594397,  60.65943992, 116.63058956,
#        132.0051142 , 125.60904215, 121.86498647,  99.60051308,
#        189.51397164, 120.7974129 , 139.39641798,  29.54422014,
#        157.18041588, 206.93621954,  96.27106126, 213.82649502,
#        123.06290011,  74.48919662, 150.53256179,  67.0701043 ,
#         73.02227807, 210.02160562, 125.37659634,  44.06375829,
#        109.65154794,  15.68968756,  12.42449446,  56.26962392,
#         77.10204267, 120.81131722, 151.28536232, 113.89431736,
#         61.78469666, 116.42287239,  78.75199867, 265.92329312,
#         66.06369007,  64.46629218,  28.65836577,  89.79560235,
#         79.95898981, 153.69602671, 109.73491832, 117.51951092,
#        139.58677174, 229.53570562,  61.42430379, 206.61172345,
#        232.38098879, 171.75568193,  52.69193334, 102.41951608,
#        214.44846611, 259.79177881,  52.31325769, 186.26717927,
#         54.63511204,  99.53874355, 205.09016031, 160.38678153,
#        188.32706979, 352.42233804, 115.75362921,  88.05882966,
#         60.49414232, 199.3903871 ,  92.03261692,  85.2708003 ,
#         77.75066073,  64.33231394, 208.6545844 , 113.75627837,
#         40.20784571,  70.98640009, 116.13194054, 169.04752643,
#        101.50987471,  57.94419061, 256.46574234,  69.22388002,
#        162.43394009, 151.68763959,  88.12067262,  59.66014065,
#        261.34548372,  92.59057437, 150.18374239,  42.2036542 ,
#         50.9325362 , 137.93583556,  25.70498845, 176.41315929,
#          7.77286465, 173.99381691, 199.75361767,  34.08356193,
#         32.16334199, 227.06814208,  68.37291638,  39.85553076,
#         51.77790337, 258.707338  , 152.96609571, 120.85788501,
#        132.48979385,  52.94455911,  70.87258552, 176.03822667,
#         42.14087782,  68.98741009, 161.69062591, 165.97309404,
#         79.00735145, 143.0958973 ,  63.34925973,  17.5583722 ,
#        166.11751544,  99.70122412, 135.05108185, 126.54165018,
#        122.77231758, 161.05289076, 110.78160907,  52.580024  ,
#         37.99623408, 293.47034467,  66.86145259,  96.04283095,
#        209.91067313,  72.44274299,  63.53579497, 170.34062494,
#         53.68121865,  69.40463722,  80.47076367, 175.04456856,
#        106.50474276, 135.57438688, 121.86131215,  82.98041342,
#         53.95964958, 121.7595396 ,  97.92025216, 265.23464204,
#        136.03926542,  96.24985882, 104.5179805 ,  89.53186135,
#         64.824819  ,  72.32873354,  24.49561769,  31.90191221,
#         96.15313129,  42.02899849,  45.86510964,  47.80044587,
#         41.60521242,  52.21482092, 248.02377899,  69.36299665])

# %% [markdown]
#     a. Reporte o RSS, SER, R2 e o MAE

# %%
print("RSS: ", RSS(sales, sales_p))
print("RSE: ", RSE(sales, sales_p))
print("R2: ", R2(sales, sales_p))
print("MAE: ", MAE(sales, sales_p))
# Out:
# RSS:  2982487.6601610975
# RSE:  122.73169513500828
# R2:  -549.5641062858205
# MAE:  103.51784088022326

# %% [markdown]
#     b. Reporte os coeficientes

# %%
print("Coeficientes: ", modelo.coef())
# Out:
# Coeficientes:  [ 4.57646455e-02  1.88530017e-01 -1.03749304e-03  2.93888937e+00]

# %% [markdown]
#     c. Ao analisar os coeficientes e o erro e comparar com a questão anterior, esse método seria mais adequado para relacionar as variáveis TV, Radio e Newspaper com a variável alvo Sales?

# %% [markdown]
# Na questão anterior, a variável que obteve maior correlação foi TV. Porém, ao analisar os coeficientes aplicando a regressão linear múltipla, a variável que teve maior correlação com sales foi radio, porque o valor obtido do coeficiente foi mais alto que os valores das demais variáveis. A variável newspaper teve um valor de coeficiente mais baixo que as demais, e, como na questão anterior, tem uma correlação menor com sales.
